# %%
import shutil
import os


documents_path = os.path.join(os.path.expanduser("~"), "Documents")

# This points to your specific internship folder and the file
source = os.path.join(documents_path, "CodeAlpha_internship", "Iris.csv")


destination = "Iris.csv"

try:
    shutil.copy(source, destination)
    print(" Success! File uploaded to your current Jupyter folder.")
except FileNotFoundError:
    print(" Still can't find it. Please check two things:")
    print(f"1. Does this folder exist: Documents/CodeAlpha_internship")
    print(f"2. Is the file inside it named exactly: Iris.csv")
# Out:
# ✅ Success! File uploaded to your current Jupyter folder.

# %%
import pandas as pd
df = pd.read_csv('Iris.csv')
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('Iris.csv')

# Look at the first 5 rows
print("Dataset loaded successfully!")
df.head()
# Out:
# Dataset loaded successfully!
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
# Check if there are any null values
print(df.isnull().sum())
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
# See the count of each species
print(df['Species'].value_counts())
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# This creates a beautiful visual grid of your data
sns.pairplot(df, hue='Species', markers=["o", "s", "D"])
plt.show()

# %%
from sklearn.model_selection import train_test_split

# X = the measurements (features)
# y = the species name (target)
X = df.drop(columns=['Species'])
y = df['Species']

# We split the data: 80% to train the model, 20% to test it
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

print("Data split successfully!")
print(f"Training samples: {len(X_train)}")
print(f"Testing samples: {len(X_test)}")
# Out:
# Data split successfully!
# Training samples: 120
# Testing samples: 30

# %%
from sklearn.linear_model import LogisticRegression

# Increase max_iter to 1000 to give the model more time to converge
model = LogisticRegression(max_iter=1000)

# Train again
model.fit(X_train, y_train)

print("Model training complete without warnings!")
# Out:
# Model training complete without warnings!

# %%
predictions = model.predict(X_test)


score = accuracy_score(y_test, predictions)

print(f"Model Accuracy: {score * 100:.2f}%")
print("\nDetailed Report:")
print(classification_report(y_test, predictions))
# Out:
# Model Accuracy: 100.00%
#
# Detailed Report:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        10
# Iris-versicolor       1.00      1.00      1.00         9
#  Iris-virginica       1.00      1.00      1.00        11
#
#        accuracy                           1.00        30
#       macro avg       1.00      1.00      1.00        30
#    weighted avg       1.00      1.00      1.00        30
